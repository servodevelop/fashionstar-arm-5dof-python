# %%
import sys
sys.path.append('../')

import math
import numpy as np
from arm5dof import Arm5DoF
from config import *

# %%
arm = Arm5DoF('COM5')
# Out:
# INFO:root:设置关节弧度, 关节#1 弧度 0.0000 角度 0.0
# INFO:root:设置关节弧度, 关节#2 弧度 -2.3562 角度 -135.0
# INFO:root:设置关节弧度, 关节#3 弧度 1.5708 角度 90.0
# INFO:root:设置关节弧度, 关节#4 弧度 0.7854 角度 45.0
# INFO:root:设置关节弧度, 关节#5 弧度 0.0000 角度 0.0

# %%
# 设置爪子的弧度
arm.set_gripper(math.radians(30), t=1.0, power=800)
# Out:
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1379 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1380 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1380 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1380 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1380 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1381 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1381 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1381 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1381 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1382 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1382 角度 7.9
# INFO:root:设置关节弧度, 关节#5 弧度 0.1383 角度 7.9
# ...

# %%
# 设置爪子的弧度
arm.set_gripper(0, t=1.0, power=800)
# Out:
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5166 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5165 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5165 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5165 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5165 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5165 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5164 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5164 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5163 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5163 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5163 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5162 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5161 角度 29.6
# INFO:root:设置关节弧度, 关节#5 弧度 0.5161 角度 29.6
# ...

# %%
# 爪子开启
arm.gripper_open()

# %%
# 爪子闭合
arm.gripper_close()
