# %% [markdown]
# ## 导入依赖

# %%
import sys
sys.path.append('../')

import math
import numpy as np
from arm5dof import Arm5DoF
from config import *

# %% [markdown]
# ## 创建机械臂

# %%
arm = Arm5DoF('COM5')
# Out:
# INFO:root:设置关节弧度, 关节#1 弧度 0.0000 角度 0.0
# INFO:root:设置关节弧度, 关节#2 弧度 -2.3562 角度 -135.0
# INFO:root:设置关节弧度, 关节#3 弧度 1.5708 角度 90.0
# INFO:root:设置关节弧度, 关节#4 弧度 0.7854 角度 45.0

# %% [markdown]
# ## 末端控制

# %%
p_tool = [15.0, -5.0, 10.0]
pitch  = math.radians(10)
arm.move(p_tool, pitch=pitch)

p_tool = [15.0, -5.0, 5.0]
pitch  = math.radians(30)
arm.move(p_tool, pitch=pitch)

p_tool = [18.0, 8.0, 10.0]
pitch  = math.radians(-10)
arm.move(p_tool, pitch=pitch)

p_tool = [15.0, 0.0, 3.0]
pitch  = math.radians(45)
arm.move(p_tool, pitch=pitch)


p_tool = [15.0, 0.0, -2.0]
pitch  = math.radians(45)
arm.move(p_tool, pitch=pitch)


p_tool = [20.0, 0.0, -2.0]
pitch  = math.radians(45)
arm.move(p_tool, pitch=pitch)

p_tool = [20.0, 0.0, -4.0]
pitch  = math.radians(60)
arm.move(p_tool, pitch=pitch)


p_tool = [15.0, 0.0, 10.0]
pitch  = math.radians(0)
arm.move(p_tool, pitch=pitch)
# Out:
# INFO:root:移动机械臂末端到: [15.0, -5.0, 10.0] Pitch=0.17453292519943295
# INFO:root:关节弧度: [-0.3217505543966422, -1.9901436634528493, 1.2625130848313846, 0.9021635038208977]
# INFO:root:关节角度: [ -18.43494882 -114.02683254   72.33667134   51.6901612 ]
# INFO:root:设置关节弧度, 关节#1 弧度 0.0079 角度 0.4
# INFO:root:设置关节弧度, 关节#2 弧度 -2.2591 角度 -129.4
# INFO:root:设置关节弧度, 关节#3 弧度 1.7440 角度 99.9
# INFO:root:设置关节弧度, 关节#4 弧度 0.5397 角度 30.9
# INFO:root:设置关节弧度, 关节#1 弧度 0.0079 角度 0.4
# INFO:root:设置关节弧度, 关节#2 弧度 -2.2591 角度 -129.4
# INFO:root:设置关节弧度, 关节#3 弧度 1.7440 角度 99.9
# INFO:root:设置关节弧度, 关节#4 弧度 0.5397 角度 30.9
# INFO:root:设置关节弧度, 关节#1 弧度 0.0079 角度 0.4
# INFO:root:设置关节弧度, 关节#2 弧度 -2.2591 角度 -129.4
# INFO:root:设置关节弧度, 关节#3 弧度 1.7440 角度 99.9
# INFO:root:设置关节弧度, 关节#4 弧度 0.5397 角度 30.9
# INFO:root:设置关节弧度, 关节#1 弧度 0.0078 角度 0.4
# INFO:root:设置关节弧度, 关节#2 弧度 -2.2591 角度 -129.4
# INFO:root:设置关节弧度, 关节#3 弧度 1.7440 角度 99.9
# INFO:root:设置关节弧度, 关节#4 弧度 0.5397 角度 30.9
# INFO:root:设置关节弧度, 关节#1 弧度 0.0078 角度 0.4
# ...

# %%
# Out:
# INFO:root:移动机械臂末端到: [20.0, 0.0, -4.0] Pitch=1.0471975511965976
# INFO:root:关节弧度: [0.0, -0.7169885379870408, 0.37887175535441064, 1.3853143338292278]
# INFO:root:关节角度: [  0.         -41.08041719  21.70775256  79.37266463]
# INFO:root:设置关节弧度, 关节#1 弧度 0.0098 角度 0.6
# INFO:root:设置关节弧度, 关节#2 弧度 -1.1760 角度 -67.4
# INFO:root:设置关节弧度, 关节#3 弧度 1.4319 角度 82.0
# INFO:root:设置关节弧度, 关节#4 弧度 0.5538 角度 31.7
# INFO:root:设置关节弧度, 关节#1 弧度 0.0098 角度 0.6
# INFO:root:设置关节弧度, 关节#2 弧度 -1.1760 角度 -67.4
# INFO:root:设置关节弧度, 关节#3 弧度 1.4319 角度 82.0
# INFO:root:设置关节弧度, 关节#4 弧度 0.5538 角度 31.7
# INFO:root:设置关节弧度, 关节#1 弧度 0.0098 角度 0.6
# INFO:root:设置关节弧度, 关节#2 弧度 -1.1760 角度 -67.4
# INFO:root:设置关节弧度, 关节#3 弧度 1.4318 角度 82.0
# INFO:root:设置关节弧度, 关节#4 弧度 0.5538 角度 31.7
# INFO:root:设置关节弧度, 关节#1 弧度 0.0098 角度 0.6
# INFO:root:设置关节弧度, 关节#2 弧度 -1.1760 角度 -67.4
# INFO:root:设置关节弧度, 关节#3 弧度 1.4318 角度 82.0
# INFO:root:设置关节弧度, 关节#4 弧度 0.5538 角度 31.7
# INFO:root:设置关节弧度, 关节#1 弧度 0.0098 角度 0.6
# ...
